// %% [markdown]
// ## 中心極限定理

// %%
// 依存関係のインストール

:dep image = "0.23"
:dep evcxr_image = "1.1"

// プロット用ライブラリ
:dep plotters = { version = "^0.3.5", default_features = false, features = ["evcxr", "all_series", "all_elements"] }

// 乱数
:dep rand = { version = "0.8.5" }

// %%
// インポート
use evcxr_image::ImageDisplay;
use image::{GenericImage, imageops::FilterType};

use plotters::prelude::*;
use rand::prelude::*;

// %% [markdown]
// ### サンプリング

// %%
/// ランダムな変数`n`個を`rep`回サンプリングする
fn sample_means(n: usize, rep: usize) -> Vec<f64> {
    (0..rep)
        .map(|_| {
            // 平均
            let mean = (0..n)
                .map(|_| random::<f64>())
                .sum::<f64>() / n as f64;
            mean
        })
        .collect()
}

// %%
const REP: usize = 10000;

// %% [markdown]
// $N = 1$ のとき

// %%
let means = sample_means(1, REP);

evcxr_figure((640, 480), |root| {
    root.fill(&WHITE)?;

    let mut chart = ChartBuilder::on(&root)
        .caption("N = 1", ("Sans", 20).into_font())
        .x_label_area_size(50)
        .y_label_area_size(50)
        .build_cartesian_2d(0..10, 0.0..40.0)?;

    chart.configure_mesh()
        .draw()?;

    let hist = Histogram::vertical(&chart)
        .style(BLUE.filled())
        .margin(10)
        .data(means.iter().map(|&x| ((x * 10.0) as i32, 0.01)));

    chart.draw_series(hist)?;
    
    Ok(())
})
// Out:
// <div style=""><svg width="640" height="480" viewBox="0 0 640 480" xmlns="http://www.w3.org/2000/svg">
// <rect x="0" y="0" width="640" height="480" opacity="1" fill="#FFFFFF" stroke="none"/>
// <text x="320" y="5" dy="0.76em" text-anchor="middle" font-family="Sans" font-size="16.129032258064516" opacity="1" fill="#000000">
// N = 1
// </text>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="429" x2="50" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="108" y1="429" x2="108" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="167" y1="429" x2="167" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="226" y1="429" x2="226" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="285" y1="429" x2="285" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="344" y1="429" x2="344" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="403" y1="429" x2="403" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="462" y1="429" x2="462" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="521" y1="429" x2="521" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="580" y1="429" x2="580" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="639" y1="429" x2="639" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="429" x2="639" y2="429"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="424" x2="639" y2="424"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="419" x2="639" y2="419"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="414" x2="639" y2="414"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="409" x2="639" y2="409"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="404" x2="639" y2="404"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="399" x2="639" y2="399"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="394" x2="639" y2="394"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="389" x2="639" y2="389"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="384" x2="639" y2="384"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="379" x2="639" y2="379"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="374" x2="639" y2="374"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="369" x2="639" y2="369"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="364" x2="639" y2="364"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="359" x2="639" y2="359"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="354" x2="639" y2="354"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="349" x2="639" y2="349"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="344" x2="639" y2="344"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="339" x2="639" y2="339"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="334" x2="639" y2="334"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="329" x2="639" y2="329"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="324" x2="639" y2="324"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="319" x2="639" y2="319"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="314" x2="639" y2="314"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="309" x2="639" y2="309"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="304" x2="639" y2="304"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="299" x2="639" y2="299"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="293" x2="639" y2="293"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="288" x2="639" y2="288"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="283" x2="639" y2="283"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="278" x2="639" y2="278"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="273" x2="639" y2="273"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="268" x2="639" y2="268"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="263" x2="639" y2="263"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="258" x2="639" y2="258"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="253" x2="639" y2="253"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="248" x2="639" y2="248"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="243" x2="639" y2="243"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="238" x2="639" y2="238"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="233" x2="639" y2="233"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="228" x2="639" y2="228"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="223" x2="639" y2="223"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="218" x2="639" y2="218"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="213" x2="639" y2="213"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="208" x2="639" y2="208"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="203" x2="639" y2="203"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="198" x2="639" y2="198"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="193" x2="639" y2="193"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="188" x2="639" y2="188"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="183" x2="639" y2="183"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="178" x2="639" y2="178"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="173" x2="639" y2="173"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="168" x2="639" y2="168"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="163" x2="639" y2="163"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="157" x2="639" y2="157"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="152" x2="639" y2="152"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="147" x2="639" y2="147"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="142" x2="639" y2="142"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="137" x2="639" y2="137"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="132" x2="639" y2="132"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="127" x2="639" y2="127"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="122" x2="639" y2="122"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="117" x2="639" y2="117"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="112" x2="639" y2="112"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="107" x2="639" y2="107"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="102" x2="639" y2="102"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="97" x2="639" y2="97"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="92" x2="639" y2="92"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="87" x2="639" y2="87"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="82" x2="639" y2="82"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="77" x2="639" y2="77"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="72" x2="639" y2="72"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="67" x2="639" y2="67"/>
// <line opacity="0.1" stroke="#000000" st

// %% [markdown]
// $N = 2$ のとき

// %%
let means = sample_means(2, REP);

evcxr_figure((640, 480), |root| {
    root.fill(&WHITE)?;

    let mut chart = ChartBuilder::on(&root)
        .caption("N = 1", ("Sans", 20).into_font())
        .x_label_area_size(50)
        .y_label_area_size(50)
        .build_cartesian_2d(0..10, 0.0..40.0)?;

    chart.configure_mesh()
        .draw()?;

    let hist = Histogram::vertical(&chart)
        .style(BLUE.filled())
        .margin(10)
        .data(means.iter().map(|&x| ((x * 10.0) as i32, 0.01)));

    chart.draw_series(hist)?;
    
    Ok(())
})
// Out:
// <div style=""><svg width="640" height="480" viewBox="0 0 640 480" xmlns="http://www.w3.org/2000/svg">
// <rect x="0" y="0" width="640" height="480" opacity="1" fill="#FFFFFF" stroke="none"/>
// <text x="320" y="5" dy="0.76em" text-anchor="middle" font-family="Sans" font-size="16.129032258064516" opacity="1" fill="#000000">
// N = 1
// </text>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="429" x2="50" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="108" y1="429" x2="108" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="167" y1="429" x2="167" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="226" y1="429" x2="226" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="285" y1="429" x2="285" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="344" y1="429" x2="344" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="403" y1="429" x2="403" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="462" y1="429" x2="462" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="521" y1="429" x2="521" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="580" y1="429" x2="580" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="639" y1="429" x2="639" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="429" x2="639" y2="429"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="424" x2="639" y2="424"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="419" x2="639" y2="419"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="414" x2="639" y2="414"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="409" x2="639" y2="409"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="404" x2="639" y2="404"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="399" x2="639" y2="399"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="394" x2="639" y2="394"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="389" x2="639" y2="389"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="384" x2="639" y2="384"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="379" x2="639" y2="379"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="374" x2="639" y2="374"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="369" x2="639" y2="369"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="364" x2="639" y2="364"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="359" x2="639" y2="359"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="354" x2="639" y2="354"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="349" x2="639" y2="349"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="344" x2="639" y2="344"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="339" x2="639" y2="339"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="334" x2="639" y2="334"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="329" x2="639" y2="329"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="324" x2="639" y2="324"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="319" x2="639" y2="319"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="314" x2="639" y2="314"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="309" x2="639" y2="309"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="304" x2="639" y2="304"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="299" x2="639" y2="299"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="293" x2="639" y2="293"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="288" x2="639" y2="288"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="283" x2="639" y2="283"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="278" x2="639" y2="278"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="273" x2="639" y2="273"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="268" x2="639" y2="268"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="263" x2="639" y2="263"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="258" x2="639" y2="258"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="253" x2="639" y2="253"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="248" x2="639" y2="248"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="243" x2="639" y2="243"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="238" x2="639" y2="238"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="233" x2="639" y2="233"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="228" x2="639" y2="228"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="223" x2="639" y2="223"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="218" x2="639" y2="218"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="213" x2="639" y2="213"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="208" x2="639" y2="208"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="203" x2="639" y2="203"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="198" x2="639" y2="198"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="193" x2="639" y2="193"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="188" x2="639" y2="188"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="183" x2="639" y2="183"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="178" x2="639" y2="178"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="173" x2="639" y2="173"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="168" x2="639" y2="168"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="163" x2="639" y2="163"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="157" x2="639" y2="157"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="152" x2="639" y2="152"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="147" x2="639" y2="147"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="142" x2="639" y2="142"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="137" x2="639" y2="137"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="132" x2="639" y2="132"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="127" x2="639" y2="127"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="122" x2="639" y2="122"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="117" x2="639" y2="117"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="112" x2="639" y2="112"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="107" x2="639" y2="107"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="102" x2="639" y2="102"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="97" x2="639" y2="97"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="92" x2="639" y2="92"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="87" x2="639" y2="87"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="82" x2="639" y2="82"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="77" x2="639" y2="77"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="72" x2="639" y2="72"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="67" x2="639" y2="67"/>
// <line opacity="0.1" stroke="#000000" st

// %% [markdown]
// $N = 4$ のとき

// %%
let means = sample_means(4, REP);

evcxr_figure((640, 480), |root| {
    root.fill(&WHITE)?;

    let mut chart = ChartBuilder::on(&root)
        .caption("N = 1", ("Sans", 20).into_font())
        .x_label_area_size(50)
        .y_label_area_size(50)
        .build_cartesian_2d(0..10, 0.0..40.0)?;

    chart.configure_mesh()
        .draw()?;

    let hist = Histogram::vertical(&chart)
        .style(BLUE.filled())
        .margin(10)
        .data(means.iter().map(|&x| ((x * 10.0) as i32, 0.01)));

    chart.draw_series(hist)?;
    
    Ok(())
})
// Out:
// <div style=""><svg width="640" height="480" viewBox="0 0 640 480" xmlns="http://www.w3.org/2000/svg">
// <rect x="0" y="0" width="640" height="480" opacity="1" fill="#FFFFFF" stroke="none"/>
// <text x="320" y="5" dy="0.76em" text-anchor="middle" font-family="Sans" font-size="16.129032258064516" opacity="1" fill="#000000">
// N = 1
// </text>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="429" x2="50" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="108" y1="429" x2="108" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="167" y1="429" x2="167" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="226" y1="429" x2="226" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="285" y1="429" x2="285" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="344" y1="429" x2="344" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="403" y1="429" x2="403" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="462" y1="429" x2="462" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="521" y1="429" x2="521" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="580" y1="429" x2="580" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="639" y1="429" x2="639" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="429" x2="639" y2="429"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="424" x2="639" y2="424"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="419" x2="639" y2="419"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="414" x2="639" y2="414"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="409" x2="639" y2="409"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="404" x2="639" y2="404"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="399" x2="639" y2="399"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="394" x2="639" y2="394"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="389" x2="639" y2="389"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="384" x2="639" y2="384"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="379" x2="639" y2="379"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="374" x2="639" y2="374"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="369" x2="639" y2="369"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="364" x2="639" y2="364"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="359" x2="639" y2="359"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="354" x2="639" y2="354"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="349" x2="639" y2="349"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="344" x2="639" y2="344"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="339" x2="639" y2="339"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="334" x2="639" y2="334"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="329" x2="639" y2="329"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="324" x2="639" y2="324"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="319" x2="639" y2="319"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="314" x2="639" y2="314"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="309" x2="639" y2="309"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="304" x2="639" y2="304"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="299" x2="639" y2="299"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="293" x2="639" y2="293"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="288" x2="639" y2="288"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="283" x2="639" y2="283"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="278" x2="639" y2="278"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="273" x2="639" y2="273"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="268" x2="639" y2="268"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="263" x2="639" y2="263"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="258" x2="639" y2="258"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="253" x2="639" y2="253"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="248" x2="639" y2="248"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="243" x2="639" y2="243"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="238" x2="639" y2="238"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="233" x2="639" y2="233"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="228" x2="639" y2="228"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="223" x2="639" y2="223"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="218" x2="639" y2="218"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="213" x2="639" y2="213"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="208" x2="639" y2="208"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="203" x2="639" y2="203"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="198" x2="639" y2="198"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="193" x2="639" y2="193"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="188" x2="639" y2="188"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="183" x2="639" y2="183"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="178" x2="639" y2="178"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="173" x2="639" y2="173"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="168" x2="639" y2="168"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="163" x2="639" y2="163"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="157" x2="639" y2="157"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="152" x2="639" y2="152"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="147" x2="639" y2="147"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="142" x2="639" y2="142"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="137" x2="639" y2="137"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="132" x2="639" y2="132"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="127" x2="639" y2="127"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="122" x2="639" y2="122"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="117" x2="639" y2="117"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="112" x2="639" y2="112"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="107" x2="639" y2="107"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="102" x2="639" y2="102"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="97" x2="639" y2="97"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="92" x2="639" y2="92"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="87" x2="639" y2="87"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="82" x2="639" y2="82"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="77" x2="639" y2="77"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="72" x2="639" y2="72"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="67" x2="639" y2="67"/>
// <line opacity="0.1" stroke="#000000" st

// %% [markdown]
// $N = 10$ のとき

// %%
let means = sample_means(10, REP);

evcxr_figure((640, 480), |root| {
    root.fill(&WHITE)?;

    let mut chart = ChartBuilder::on(&root)
        .caption("N = 1", ("Sans", 20).into_font())
        .x_label_area_size(50)
        .y_label_area_size(50)
        .build_cartesian_2d(0..20, 0.0..40.0)?;

    chart.configure_mesh()
        .draw()?;

    let hist = Histogram::vertical(&chart)
        .style(BLUE.filled())
        .margin(5)
        .data(means.iter().map(|&x| ((x * 20.0) as i32, 0.01)));

    chart.draw_series(hist)?;
    
    Ok(())
})
// Out:
// <div style=""><svg width="640" height="480" viewBox="0 0 640 480" xmlns="http://www.w3.org/2000/svg">
// <rect x="0" y="0" width="640" height="480" opacity="1" fill="#FFFFFF" stroke="none"/>
// <text x="320" y="5" dy="0.76em" text-anchor="middle" font-family="Sans" font-size="16.129032258064516" opacity="1" fill="#000000">
// N = 1
// </text>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="429" x2="50" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="79" y1="429" x2="79" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="108" y1="429" x2="108" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="138" y1="429" x2="138" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="167" y1="429" x2="167" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="197" y1="429" x2="197" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="226" y1="429" x2="226" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="256" y1="429" x2="256" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="285" y1="429" x2="285" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="315" y1="429" x2="315" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="344" y1="429" x2="344" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="373" y1="429" x2="373" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="403" y1="429" x2="403" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="432" y1="429" x2="432" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="462" y1="429" x2="462" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="491" y1="429" x2="491" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="521" y1="429" x2="521" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="550" y1="429" x2="550" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="580" y1="429" x2="580" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="609" y1="429" x2="609" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="639" y1="429" x2="639" y2="26"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="429" x2="639" y2="429"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="424" x2="639" y2="424"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="419" x2="639" y2="419"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="414" x2="639" y2="414"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="409" x2="639" y2="409"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="404" x2="639" y2="404"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="399" x2="639" y2="399"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="394" x2="639" y2="394"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="389" x2="639" y2="389"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="384" x2="639" y2="384"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="379" x2="639" y2="379"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="374" x2="639" y2="374"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="369" x2="639" y2="369"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="364" x2="639" y2="364"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="359" x2="639" y2="359"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="354" x2="639" y2="354"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="349" x2="639" y2="349"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="344" x2="639" y2="344"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="339" x2="639" y2="339"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="334" x2="639" y2="334"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="329" x2="639" y2="329"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="324" x2="639" y2="324"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="319" x2="639" y2="319"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="314" x2="639" y2="314"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="309" x2="639" y2="309"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="304" x2="639" y2="304"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="299" x2="639" y2="299"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="293" x2="639" y2="293"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="288" x2="639" y2="288"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="283" x2="639" y2="283"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="278" x2="639" y2="278"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="273" x2="639" y2="273"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="268" x2="639" y2="268"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="263" x2="639" y2="263"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="258" x2="639" y2="258"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="253" x2="639" y2="253"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="248" x2="639" y2="248"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="243" x2="639" y2="243"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="238" x2="639" y2="238"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="233" x2="639" y2="233"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="228" x2="639" y2="228"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="223" x2="639" y2="223"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="218" x2="639" y2="218"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="213" x2="639" y2="213"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="208" x2="639" y2="208"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="203" x2="639" y2="203"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="198" x2="639" y2="198"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="193" x2="639" y2="193"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="188" x2="639" y2="188"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="183" x2="639" y2="183"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="178" x2="639" y2="178"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="173" x2="639" y2="173"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="168" x2="639" y2="168"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="163" x2="639" y2="163"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="157" x2="639" y2="157"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="152" x2="639" y2="152"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="147" x2="639" y2="147"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="142" x2="639" y2="142"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="137" x2="639" y2="137"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="132" x2="639" y2="132"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="127" x2="639" y2="127"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="122" x2="639" y2="122"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="50" y1="117" x2="639" y2="117"/>
// <line opacity="0.1" stroke=
